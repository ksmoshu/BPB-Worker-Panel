# %% [markdown]
# <a href="https://colab.research.google.com/github/ksmoshu/BPB-Worker-Panel/blob/main/%E9%AB%98%E9%80%9F%E8%8A%82%E7%82%B9%E6%8A%93%E5%8F%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/wzdnzd/aggregator.git
# Out:
# Cloning into 'aggregator'...
# remote: Enumerating objects: 3812, done.
# remote: Total 3812 (delta 0), reused 0 (delta 0), pack-reused 3812 (from 1)
# Receiving objects: 100% (3812/3812), 725.93 MiB | 19.71 MiB/s, done.
# Resolving deltas: 100% (2247/2247), done.
# Updating files: 100% (509/509), done.

# %%
# %cd aggregator
# Out:
# /content/aggregator

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 7.0 MB/s eta 0:00:00
# ...
#   Created wheel for fofa-hack: filename=fofa_hack-2.5.2-py3-none-any.whl size=31469 sha256=6bd1db7e6623a26c8130252e04a6b3a10887f6283f36d7eed6a41f04dfde5fdc
#   Stored in directory: /root/.cache/pip/wheels/be/24/dd/2a217b13b9f502c53f1c1212b2025abb144311371b77f848b3
# Successfully built fofa-hack
# ...

# %%
# !python -u subscribe/collect.py -s
# Out:
# 2025-06-18 00:30:42 collect.py [line:205] ERROR: cannot extract username and gist id due to invalid github gist link
# 2025-06-18 00:30:42 collect.py [line:68] INFO: start checking whether existing subscriptions have expired
# 2025-06-18 00:30:42 collect.py [line:110] INFO: load exists subscription finished, count: 0
# 2025-06-18 00:30:42 crawl.py [line:1434] INFO: [TelegramCrawl] starting crawl from telegram, channel: jichang_list, pages: 213
# 2025-06-18 00:30:42 crawl.py [line:1394] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4256
# 2025-06-18 00:30:42 crawl.py [line:1394] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4236
# 2025-06-18 00:30:42 crawl.py [line:1394] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4216
# 2025-06-18 00:30:42 crawl.py [line:1394] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4196
# ...

# %%
# !cat /content/aggregator/data/v2ray.txt
# Out:
# ...

# %%
import base64

encoded_string = "..."

decoded_string = base64.b64decode(encoded_string).decode('utf-8')
print(decoded_string)
# Out:
# vmess:
# vmess:
# vmess:
# ...
